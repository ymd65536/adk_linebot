# %%
! pip install google-cloud-aiplatform[adk,agent_engines]
# Out:
# Requirement already satisfied: google-cloud-aiplatform[adk,agent_engines] in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.95.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.25.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.40.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (6.31.1)
# Requirement already satisfied: packaging>=14.3 in /home/codespace/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (3.34.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.1.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.18.0)
# Requirement already satisfied: pydantic<3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.11.5)
# Requirement already satisfied: typing-extensions in /home/codespace/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (4.12.2)
# Requirement already satisfied: docstring-parser<1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (0.16)
# Requirement already satisfied: google-adk<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.1.1)
# Collecting cloudpickle<4.0,>=3.0 (from google-cloud-aiplatform[adk,agent_engines])
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.16.1)
# Collecting google-cloud-logging<4 (from google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_logging-3.12.1-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: opentelemetry-sdk<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.9.0)
# Requirement already satisfied: authlib>=1.5.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.6.0)
# Requirement already satisfied: click>=8.1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (8.2.1)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.115.12)
# Requirement already satisfied: google-api-python-client>=2.157.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.171.0)
# Requirement already satisfied: google-cloud-secret-manager>=2.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.23.3)
# Requirement already satisfied: google-cloud-speech>=2.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.32.0)
# Requirement already satisfied: graphviz>=0.20.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.20.3)
# Requirement already satisfied: mcp>=1.5.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.9.2)
# Requirement already satisfied: opentelemetry-api>=1.31.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.33.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.1.0)
# Requirement already satisfied: PyYAML>=6.0.2 in /home/codespace/.local/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (6.0.2)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.0.41)
# Requirement already satisfied: tzlocal>=5.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (5.3.1)
# Requirement already satisfied: uvicorn>=0.34.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.34.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.72.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.72.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (4.9.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.9.0.post0)
# Collecting google-cloud-appengine-logging<2.0.0,>=0.1.3 (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_appengine_logging-1.6.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting google-cloud-audit-log<1.0.0,>=0.3.1 (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_audit_log-0.3.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]) (0.14.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform[adk,agent_engines]) (1.7.1)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (4.9.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/codespace/.local/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (15.0.1)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-exporter-gcp-trace<2->google-cloud-aiplatform[adk,agent_engines]) (1.9.0a0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-sdk<2->google-cloud-aiplatform[adk,agent_engines]) (0.54b1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api>=1.31.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from opentelemetry-api>=1.31.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]) (0.4.1)
# Requirement already satisfied: numpy>=1.21 in /home/codespace/.local/lib/python3.12/site-packages (from shapely<3.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.2.4)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/python/3.12.1/lib/python3.12/site-packages (from authlib>=1.5.1->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (45.0.3)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from fastapi>=0.115.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.46.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from google-api-python-client>=2.157.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (4.2.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.14.0)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.4.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.9.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.3.6)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (0.6.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from sqlalchemy>=2.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (3.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.31.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.17.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/codespace/.local/lib/python3.12/site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=2.157.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (3.2.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.31.0->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (3.22.0)
# Requirement already satisfied: cffi>=1.14 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography->authlib>=1.5.1->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.17.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.14->cryptography->authlib>=1.5.1->google-adk<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.22)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading google_cloud_logging-3.12.1-py2.py3-none-any.whl (229 kB)
# Downloading google_cloud_appengine_logging-1.6.1-py3-none-any.whl (16 kB)
# Downloading google_cloud_audit_log-0.3.2-py3-none-any.whl (32 kB)
# Installing collected packages: cloudpickle, google-cloud-audit-log, google-cloud-appengine-logging, google-cloud-logging
# Successfully installed cloudpickle-3.1.1 google-cloud-appengine-logging-1.6.1 google-cloud-audit-log-0.3.2 google-cloud-logging-3.12.1
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import agents.human.main_agent as root_agent
from vertexai import agent_engines

remote_app = agent_engines.create(
    agent_engine=root_agent,
    requirements=[
        "google-cloud-aiplatform[adk,agent_engines]",
    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 import agents.human.main_agent as root_agent
#       2 from vertexai import agent_engines
# ----> 4 remote_app = agent_engines.create(
#       5     agent_engine=root_agent,
#       6     requirements=[
#       7         "google-cloud-aiplatform[adk,agent_engines]",
#       8     ]
#       9 )
#
# File ~/.python/current/lib/python3.12/site-packages/vertexai/agent_engines/__init__.py:148, in create(agent_engine, requirements, display_name, description, gcs_dir_name, extra_packages, env_vars)
#      62 def create(
#      63     agent_engine: Optional[Union[Queryable, OperationRegistrable]] = None,
#      64     *,
#    (...)     72     ] = None,
#      73 ) -> AgentEngine:
#      74     """Creates a new Agent Engine.
#      75
#      76     The Agent Engine will be an instance of the `agent_engine` that
#    (...)    146         nonexistent file.
#     147     """
# --> 148     return AgentEngine.create(
#     149         agent_engine=agent_engine,
#     150         requirements=requirements,
#     151         display_name=display_name,
#     152         description=description,
#     153         gcs_dir_name=gcs_dir_name,
#     154         extra_packages=extra_packages,
#     155         env_vars=env_vars,
#     156     )
#
# File ~/.python/current/lib/python3.12/site-packages/vertexai/agent_engines/_agent_engines.py:395, in AgentEngine.create(cls, agent_engine, requirements, display_name, description, gcs_dir_name, extra_packages, env_vars)
#     393 staging_bucket = initializer.global_config.staging_bucket
#     394 if agent_engine is not None:
# --> 395     agent_engine = _validate_agent_engine_or_raise(agent_engine)
#     396     _validate_staging_bucket_or_raise(staging_bucket)
#     397 if agent_engine is None:
#
# File ~/.python/current/lib/python3.12/site-packages/vertexai/agent_engines/_agent_engines.py:783, in _validate_agent_engine_or_raise(agent_engine)
#     772 is_operation_registrable = isinstance(
#     773     agent_engine, OperationRegistrable
#     774 ) and callable(agent_engine.register_operations)
#     776 if not (
#     777     is_queryable
#     778     or is_async_queryable
#    (...)    781     or is_async_stream_queryable
#     782 ):
# --> 783     raise TypeError(
#     784         "agent_engine has none of the following callable methods: "
#     785         "`query`, `async_query`, `stream_query`, `async_stream_query` or "
#     786         "`register_operations`."
#     787     )
#     789 if is_queryable:
#     790     try:
#
# TypeError: agent_engine has none of the following callable methods: `query`, `async_query`, `stream_query`, `async_stream_query` or `register_operations`.
